# %% [markdown]
# ## Importing libraries and data

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import os
import operator
import matplotlib.pyplot as plt
import tensorflow as tf
from keras import Input
from keras.models import Sequential
from keras.models import Model
from keras.layers import Conv1D, Conv2D, Dense, BatchNormalization, Flatten, MaxPooling2D, Activation
from keras.layers import Dense, Dropout
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.preprocessing.image import ImageDataGenerator 
from sklearn.metrics import confusion_matrix, accuracy_score, ConfusionMatrixDisplay

# %%
#download the weather images and put them in a directory
path = r'C:\Users\asicz\OneDrive\Dokumenty\CareerFoundry_Data_Analyst_Course\Machine Learning with Python\Achievement2\weather\Multi-class Weather Dataset'
folders = os.listdir(path)
print(folders)
# Out:
# ['Cloudy', 'Rain', 'Shine', 'Sunrise']

# %%
#this will load in the pictures and rescale them to 250x250pixels

datagenerator = ImageDataGenerator(rescale=1/255, validation_split=0.2)
train_generator = datagenerator.flow_from_directory(
    path,
    target_size=(250 , 250),
    batch_size=32,
    subset='training',
)

test_generator = datagenerator.flow_from_directory(
    path,
    target_size=(250 , 250),
    batch_size=32,
    subset='validation',
)
# Out:
# Found 901 images belonging to 4 classes.
# Found 224 images belonging to 4 classes.

# %% [markdown]
# ## Prepare CNN model

# %%
#this is a CNN to categorize the weather images

inputs = Input(shape=(250, 250, 3))

x = Conv2D(32, (5,5), activation = 'relu')(inputs)
x = MaxPooling2D(3,3)(x)
x = Conv2D(64, (5,5) , activation = 'relu')(x)
x = MaxPooling2D((3,3))(x)
x = Conv2D(128 , (5,5) , activation = 'relu')(x)
x = MaxPooling2D(3,3)(x)
x = Flatten()(x)
x = Dropout(0.5, seed = 5)(x)
x = Dense(128 , activation = 'relu')(x)

outputs = Dense(4, activation = 'softmax')(x)

model:Model = Model(inputs=inputs, outputs=outputs)

# %%
#compile and run the model
#how many epochs are required to generate an accurate model?

model.compile(optimizer="Adam", loss="mean_squared_error", metrics=["accuracy"])
model.fit(
    train_generator, 
    epochs = 60, #<----FILL THIS IN!
    steps_per_epoch = train_generator.n // train_generator.batch_size-1,
    validation_data = test_generator,
    validation_steps = test_generator.n // test_generator.batch_size-1,
)
# Out:
# Epoch 1/60
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 45s 2s/step - accuracy: 0.9618 - loss: 0.0149 - val_accuracy: 0.9115 - val_loss: 0.0329
# Epoch 2/60
#  2/27 ━━━━━━━━━━━━━━━━━━━━ 26s 1s/step - accuracy: 0.9531 - loss: 0.0112
# C:\Users\asicz\anaconda3\Lib\contextlib.py:158: UserWarning: Your input ran out of data; interrupting training. Make sure that your dataset or generator can generate at least `steps_per_epoch * epochs` batches. You may need to use the `.repeat()` function when building your dataset.
#   self.gen.throw(typ, value, traceback)
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 3s 58ms/step - accuracy: 0.9676 - loss: 0.0091 - val_accuracy: 0.7188 - val_loss: 0.1120
# Epoch 3/60
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 41s 2s/step - accuracy: 0.9699 - loss: 0.0126 - val_accuracy: 0.8854 - val_loss: 0.0433
# Epoch 4/60
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 3s 62ms/step - accuracy: 1.0000 - loss: 1.1297e-04 - val_accuracy: 0.8125 - val_loss: 0.0690
# Epoch 5/60
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 49s 2s/step - accuracy: 0.9526 - loss: 0.0190 - val_accuracy: 0.8229 - val_loss: 0.0788
# Epoch 6/60
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 4s 79ms/step - accuracy: 0.9352 - loss: 0.0271 - val_accuracy: 0.7500 - val_loss: 0.1239
# Epoch 7/60
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 43s 1s/step - accuracy: 0.9687 - loss: 0.0106 - val_accuracy: 0.8750 - val_loss: 0.0521
# Epoch 8/60
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 3s 71ms/step - accuracy: 1.0000 - loss: 5.0181e-04 - val_accuracy: 0.9062 - val_loss: 0.0496
# Epoch 9/60
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 66s 2s/step - accuracy: 0.9830 - loss: 0.0074 - val_accuracy: 0.8854 - val_loss: 0.0535
# Epoch 10/60
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 3s 94ms/step - accuracy: 0.9740 - loss: 0.0097 - val_accuracy: 0.8750 - val_loss: 0.0423
# Epoch 11/60
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 60s 2s/step - accuracy: 0.9863 - loss: 0.0064 - val_accuracy: 0.9115 - val_loss: 0.0439
# Epoch 12/60
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 4s 85ms/step - accuracy: 1.0000 - loss: 0.0014 - val_accuracy: 0.8750 - val_loss: 0.0551
# Epoch 13/60
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 52s 2s/step - accuracy: 0.9929 - loss: 0.0027 - val_accuracy: 0.8698 - val_loss: 0.0551
# Epoch 14/60
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 5s 137ms/step - accuracy: 0.9236 - loss: 0.0283 - val_accuracy: 0.9062 - val_loss: 0.0430
# Epoch 15/60
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 63s 2s/step - accuracy: 0.9844 - loss: 0.0069 - val_accuracy: 0.8490 - val_loss: 0.0672
# Epoch 16/60
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 3s 73ms/step - accuracy: 0.9352 - loss: 0.0251 - val_accuracy: 0.8438 - val_loss: 0.0793
# Epoch 17/60
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 52s 2s/step - accuracy: 0.9582 - loss: 0.0152 - val_accuracy: 0.8333 - val_loss: 0.0699
# Epoch 18/60
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 6s 135ms/step - accuracy: 0.9525 - loss: 0.0211 - val_accuracy: 0.7188 - val_loss: 0.1167
# Epoch 19/60
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 70s 2s/step - accuracy: 0.9594 - loss: 0.0171 - val_accuracy: 0.8906 - val_loss: 0.0443
# Epoch 20/60
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 12s 378ms/step - accuracy: 1.0000 - loss: 3.8823e-04 - val_accuracy: 0.9062 - val_loss: 0.0430
# Epoch 21/60
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 197s 7s/step - accuracy: 0.9890 - loss: 0.0043 - val_accuracy: 0.8802 - val_loss: 0.0531
# Epoch 22/60
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 10s 222ms/step - accuracy: 1.0000 - loss: 3.2702e-05 - val_accuracy: 0.9062 - val_loss: 0.0441
# Epoch 23/60
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 185s 7s/step - accuracy: 0.9880 - loss: 0.0039 - val_accuracy: 0.8750 - val_loss: 0.0581
# Epoch 24/60
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 9s 200ms/step - accuracy: 0.9699 - loss: 0.0123 - val_accuracy: 0.9062 - val_loss: 0.0484
# Epoch 25/60
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 109s 4s/step - accuracy: 0.9534 - loss: 0.0184 - val_accuracy: 0.8802 - val_loss: 0.0543
# Epoch 26/60
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 12s 370ms/step - accuracy: 0.9850 - loss: 0.0084 - val_accuracy: 0.9062 - val_loss: 0.0378
# Epoch 27/60
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 60s 2s/step - accuracy: 0.9783 - loss: 0.0087 - val_accuracy: 0.9010 - val_loss: 0.0409
# Epoch 28/60
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 3s 64ms/step - accuracy: 0.9838 - loss: 0.0058 - val_accuracy: 0.8750 - val_loss: 0.0524
# Epoch 29/60
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 41s 1s/step - accuracy: 0.9882 - loss: 0.0052 - val_accuracy: 0.8854 - val_loss: 0.0470
# Epoch 30/60
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 3s 66ms/step - accuracy: 0.9537 - loss: 0.0190 - val_accuracy: 0.9062 - val_loss: 0.0469
# Epoch 31/60
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 43s 1s/step - accuracy: 0.9854 - loss: 0.0055 - val_accuracy: 0.8750 - val_loss: 0.0488
# Epoch 32/60
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 2s 51ms/step - accuracy: 0.9537 - loss: 0.0134 - val_accuracy: 0.8438 - val_loss: 0.0627
# Epoch 33/60
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 37s 1s/step - accuracy: 0.9943 - loss: 0.0028 - val_accuracy: 0.8750 - val_loss: 0.0564
# Epoch 34/60
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 3s 63ms/step - accuracy: 0.9676 - loss: 0.0084 - val_accuracy: 0.8438 - val_loss: 0.0593
# Epoch 35/60
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 42s 1s/step - accuracy: 0.9601 - loss: 0.0145 - val_accuracy: 0.7604 - val_loss: 0.1146
# Epoch 36/60
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 3s 60ms/step - accuracy: 0.8426 - loss: 0.0632 - val_accuracy: 0.7500 - val_loss: 0.1052
# Epoch 37/60
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 40s 1s/step - accuracy: 0.9407 - loss: 0.0235 - val_accuracy: 0.8542 - val_loss: 0.0615
# Epoch 38/60
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 3s 59ms/step - accuracy: 0.9838 - loss: 0.0043 - val_accuracy: 0.7812 - val_loss: 0.0883
# Epoch 39/60
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 42s 1s/step - accuracy: 0.9846 - loss: 0.0057 - val_accuracy: 0.8958 - val_loss: 0.0477
# Epoch 40/60
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 3s 68ms/step - accuracy: 0.9850 - loss: 0.0034 - val_accuracy: 0.8438 - val_loss: 0.0696
# Epoch 41/60
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 41s 1s/step - accuracy: 0.9546 - loss: 0.0187 - val_accuracy: 0.8958 - val_loss: 0.0433
# Epoch 42/60
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 3s 66ms/step - accuracy: 0.9375 - loss: 0.0296 - val_accuracy: 0.8125 - val_loss: 0.0779
# Epoch 43/60
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 39s 1s/step - accuracy: 0.9737 - loss: 0.0112 - val_accuracy: 0.8646 - val_loss: 0.0550
# Epoch 44/60
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 3s 80ms/step - accuracy: 1.0000 - loss: 4.0058e-04 - val_accuracy: 0.9375 - val_loss: 0.0162
# Epoch 45/60
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 48s 2s/step - accuracy: 0.9893 - loss: 0.0049 - val_accuracy: 0.8958 - val_loss: 0.0434
# Epoch 46/60
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 3s 65ms/step - accuracy: 1.0000 - loss: 0.0030 - val_accuracy: 0.7812 - val_loss: 0.0917
# Epoch 47/60
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 328s 12s/step - accuracy: 0.9927 - loss: 0.0033 - val_accuracy: 0.8698 - val_loss: 0.0587
# Epoch 48/60
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 3s 70ms/step - accuracy: 0.9688 - loss: 0.0175 - val_accuracy: 0.8750 - val_loss: 0.0565
# Epoch 49/60
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 46s 2s/step - accuracy: 0.9603 - loss: 0.0175 - val_accuracy: 0.8177 - val_loss: 0.0873
# Epoch 50/60
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 3s 68ms/step - accuracy: 0.9514 - loss: 0.0228 - val_accuracy: 0.8750 - val_loss: 0.0590
# Epoch 51/60
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 48s 2s/step - accuracy: 0.9592 - loss: 0.0169 - val_accuracy: 0.8646 - val_loss: 0.0612
# Epoch 52/60
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 3s 65ms/step - accuracy: 0.9537 - loss: 0.0198 - val_accuracy: 0.7812 - val_loss: 0.0870
# Epoch 53/60
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 39s 1s/step - accuracy: 0.9763 - loss: 0.0100 - val_accuracy: 0.8594 - val_loss: 0.0664
# Epoch 54/60
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 2s 52ms/step - accuracy: 1.0000 - loss: 0.0015 - val_accuracy: 0.9688 - val_loss: 0.0159
# Epoch 55/60
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 54s 2s/step - accuracy: 0.9911 - loss: 0.0040 - val_accuracy: 0.8802 - val_loss: 0.0578
# Epoch 56/60
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 3s 66ms/step - accuracy: 1.0000 - loss: 8.9786e-04 - val_accuracy: 0.8438 - val_loss: 0.0547
# Epoch 57/60
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 44s 2s/step - accuracy: 0.9866 - loss: 0.0055 - val_accuracy: 0.8802 - val_loss: 0.0565
# Epoch 58/60
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 4s 92ms/step - accuracy: 0.9838 - loss: 0.0077 - val_accuracy: 0.8750 - val_loss: 0.0626
# Epoch 59/60
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 48s 2s/step - accuracy: 0.9936 - loss: 0.0038 - val_accuracy: 0.8958 - val_loss: 0.0489
# Epoch 60/60
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 2s 78ms/step - accuracy: 1.0000 - loss: 1.7990e-04 - val_accuracy: 0.9062 - val_loss: 0.0467

# %%
results = pd.DataFrame(model.history.history)

# %% [markdown]
# ## Model evaluation

# %%
results[['loss','val_loss']].plot(title='Model Loss')
plt.savefig('./loss.png')

# %%
results[['accuracy','val_accuracy']].plot(title='Model Acurracy')
plt.savefig('./accuracy.png')

# %%
# Print the accuracy and loss
print("Accuracy: {}, Val_Accuracy: {}".format(results['accuracy'].iloc[-1], results['val_accuracy'].iloc[-1]))
print("Loss: {}, Val_Loss: {}".format(results['loss'].iloc[-1], results['val_loss'].iloc[-1]))
# Out:
# Accuracy: 1.0, Val_Accuracy: 0.90625
# Loss: 0.00018681990331970155, Val_Loss: 0.04671378433704376

# %%
# collect n batches of images and display the confusion matrix for them.

class_names = ['Cloudy', 'Rain', 'Shine', 'Sunrise']
n = 10 #<--you can change the number of batches selected.

image_batch, classes_batch = next(test_generator)

for batch in range(n):
    temp = next(test_generator)
    image_batch = np.concatenate((image_batch, temp[0]))
    classes_batch = np.concatenate((classes_batch, temp[1]))

classes_batch = classes_batch
y_predict = model.predict(image_batch)

#Confusion matrix for training data
cm = confusion_matrix(y_pred = [np.argmax(x) for x in y_predict], y_true = [np.argmax(x) for x in classes_batch])
disp = ConfusionMatrixDisplay(confusion_matrix=cm)
disp.plot()
plt.show()
# Out:
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 4s 307ms/step

# %%
#This function will display a number of random images as well as the predictions for the type of weather.

def predict_one(model, num_images = None):  
    image_batch, classes_batch = next(test_generator)
    predicted_batch = model.predict(image_batch)
    for k in range(0,image_batch.shape[0] if num_images is None else num_images):
        image = image_batch[k]
        real_class = class_names[np.argmax(classes_batch[k])]
        predicted_class = class_names[np.argmax(predicted_batch[k])]
        value_predicted = predicted_batch[k]
        isTrue = (real_class == predicted_class)
        plt.figure(k)
        plt.title(str("Correct Prediction" if isTrue else "Incorrect Prediction") + ' - class: ' + real_class + ' - ' + 'predicted: ' + predicted_class + str(value_predicted))
        plt.axis('off')
        plt.savefig('./' + real_class + '_' + predicted_class + '_' + str(value_predicted) + '.png')
        plt.imshow(image)

# %%
predict_one(model, 4) #<--you can show multiple pictures with this command. Just fill in the number you want to see.
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 321ms/step
